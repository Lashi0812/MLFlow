# %% [markdown]
# <a href="https://colab.research.google.com/github/Lashi0812/MLFlow/blob/master/Run_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Lashi0812/MLFlow.git
# Out:
# Cloning into 'MLFlow'...
# remote: Enumerating objects: 144, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 144 (delta 61), reused 111 (delta 31), pack-reused 0
# Receiving objects: 100% (144/144), 36.91 KiB | 12.30 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# !pip install mlflow

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %%
import os

# %%
os.chdir("MLFlow/Chapter07")

# %%
# !pwd
# Out:
# /content/MLFlow/Chapter07

# %%
# !mlflow run . --experiment-name Inference -P pipeline_steps=download_data,finetune_model,inference_model -P tracking_uri=https://47de-49-37-219-154.in.ngrok.io -P s3_uri=https://6646-49-37-219-154.in.ngrok.io
# Out:
# 2023/03/27 09:42:05 INFO mlflow.projects: 'Inference' does not exist. Creating a new experiment
# 2023/03/27 09:42:06 INFO mlflow.utils.conda: === Creating conda environment mlflow-2f5cb37705f8daff9937148b64de70595dbfdb0b ===
# ...
# Solving environment: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# 2023/03/27 09:46:31 INFO mlflow.projects.utils: === Created directory /tmp/tmp40l960ed for downloading remote URIs passed to arguments of type 'path' ===
# 2023/03/27 09:46:31 INFO mlflow.projects.backend.local: === Running command 'source activate mlflow-2f5cb37705f8daff9937148b64de70595dbfdb0b 1>&2 && python main.py --steps download_data,finetune_model,inference_model --tracking_uri https://47de-49-37-219-154.in.ngrok.io --s3_uri https://6646-49-37-219-154.in.ngrok.io' in run with ID '57fc2e71cdd44bfdbbcf8c57b51c4cfd' ===
# 2023-03-27 09:46:34,196 pipeline experiment_id is 3
# ...

# %%
# !mlflow run https://github.com/Lashi0812/MLFlow#Chapter07 --experiment-name Inference \
    -P pipeline_steps=download_data,finetune_model,inference_model \
    -P tracking_uri=https://47de-49-37-219-154.in.ngrok.io \
    -P s3_uri=https://6646-49-37-219-154.in.ngrok.io
# Out:
# 2023/03/27 09:54:25 INFO mlflow.projects.utils: === Fetching project from https://github.com/Lashi0812/MLFlow#Chapter07 into /tmp/tmpzqxldzuh ===
# 2023/03/27 09:54:27 INFO mlflow.projects.utils: Fetched 'master' branch
# 2023/03/27 09:54:27 INFO mlflow.utils.conda: Conda environment mlflow-2f5cb37705f8daff9937148b64de70595dbfdb0b already exists.
# 2023/03/27 09:54:27 INFO mlflow.projects.utils: === Created directory /tmp/tmpdp4cu2az for downloading remote URIs passed to arguments of type 'path' ===
# 2023/03/27 09:54:27 INFO mlflow.projects.backend.local: === Running command 'source activate mlflow-2f5cb37705f8daff9937148b64de70595dbfdb0b 1>&2 && python main.py --steps download_data,finetune_model,inference_model --tracking_uri https://47de-49-37-219-154.in.ngrok.io --s3_uri https://6646-49-37-219-154.in.ngrok.io' in run with ID 'ae177df559a744f5817f2be6231642e7' ===
# 2023-03-27 09:54:29,680 pipeline experiment_id is 3
# ...
